# %% [markdown]
# # コンピュータと音楽：松原担当分第3回

# %% [markdown]
# ## 目標

# %% [markdown]
# - Pythonの環境構築
# - GitHubの環境構築
# - MIDIファイルのインポート
# - MIDIファイルの分析

# %% [markdown]
# ### Pythonの環境構築

# %% [markdown]
# - Anaconda 3.6をインストールする
# - ターミナルでmidoモジュールのインストール

# %% [markdown]
# % sudo pip mido

# %% [markdown]
# ### GitHubの環境構築

# %% [markdown]
# - GitHubのアカウント取得
# - GitHub Desktopのインストール

# %% [markdown]
# midoモジュールをインポート
# 詳しいdocは https://mido.readthedocs.io/en/latest/ を参照

# %% [markdown]
# ### MIDIファイルのインポート

# %%
import mido

# %% [markdown]
# midiファイルの読み込み
# mid = mido.MidiFile('__midiファイルのあるパスの名前__')
# dataはStanford大学のCCARH (http://www.ccarh.org) より

# %%
mid = mido.MidiFile('./data/invention/BWV772.mid')

# %%
for i, track in enumerate(mid.tracks):
    print('Track {}: {}'.format(i, track.name))
    for msg in track:
        print(msg)
# Out:
# Track 0:
# <meta message time_signature numerator=4 denominator=4 clocks_per_click=24 notated_32nd_notes_per_beat=8 time=0>
# <meta message set_tempo tempo=697674 time=0>
# <meta message end_of_track time=0>
# Track 1:
# <meta message text text='RH' time=0>
# note_on channel=0 note=60 velocity=64 time=60
# note_off channel=0 note=60 velocity=64 time=60
# note_on channel=0 note=62 velocity=64 time=0
# note_off channel=0 note=62 velocity=64 time=60
# note_on channel=0 note=64 velocity=64 time=0
# note_off channel=0 note=64 velocity=64 time=60
# note_on channel=0 note=65 velocity=64 time=0
# note_off channel=0 note=65 velocity=64 time=60
# note_on channel=0 note=62 velocity=64 time=0
# note_off channel=0 note=62 velocity=64 time=60
# note_on channel=0 note=64 velocity=64 time=0
# note_off channel=0 note=64 velocity=64 time=60
# note_on channel=0 note=60 velocity=64 time=0
# note_off channel=0 note=60 velocity=64 time=60
# note_on channel=0 note=67 velocity=64 time=0
# ...
